# %% [markdown]
# <a href="https://colab.research.google.com/github/Karkinisal10/Coursera/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# In this text we will discuss about data science tools

# %% [markdown]
# **Objectives:**
#
# *   List poplar datascience tools
# *   List datascience language
# *   To create Table in Notebook
# *   To write comment in notebook

# %% [markdown]
# Some of the popular data science languages are
#
# 1.   Python
# 2.   R
# 3.  Javascript
# 4.  Julia

# %% [markdown]
# Some of the most commonly used libraries in ds are:
#
#
# 1.   Numpy
# 2.   pandas
# 3.   Matplotlib

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | TensorFlow         |
# | Kaggle Notebook    |

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
(3*4)+5
#This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %%
a = 200
b = 200/60
print("200 minutes to hours is ",b)
#This will convert 200 minutes to hours by diving by 60
# Out:
# 200 minutes to hours is  3.3333333333333335

# %% [markdown]
# <h2> Author</h2>
# Nishal Karki
